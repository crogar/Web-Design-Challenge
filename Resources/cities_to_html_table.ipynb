# %% [markdown]
# # Exporting csv to html

# %%
import pandas as pd

# %%
df = pd.read_csv("./cities.csv")

# %%
df['Date'] = df['Date'].astype('int64')

# %%
df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  puerto ayora  -0.7393  -90.3518     84.20      79.0        40.0
# 1        1   yellowknife  62.4560 -114.3525     -7.01      77.0        90.0
# 2        2        hobart -42.8794  147.3294     48.99      76.0        40.0
# 3        3       deshnok  27.7986   73.3447     64.51      23.0         0.0
# 4        4        albany  42.6001  -73.9662     24.01      30.0         0.0
#
#    Wind Speed Country        Date
# 0       13.80      EC  1614710662
# 1       12.66      CA  1614710662
# 2        5.75      AU  1614710662
# 3        3.51      IN  1614710663
# 4        5.01      US  1614710663

# %%
html_table = df.to_html(index=False)

# %%
print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>puerto ayora</td>
#       <td>-0.7393</td>
#       <td>-90.3518</td>
#       <td>84.20</td>
#       <td>79.0</td>
#       <td>40.0</td>
#       <td>13.80</td>
#       <td>EC</td>
#       <td>1614710662</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>yellowknife</td>
#       <td>62.4560</td>
#       <td>-114.3525</td>
#       <td>-7.01</td>
#       <td>77.0</td>
#       <td>90.0</td>
#       <td>12.66</td>
#       <td>CA</td>
#       <td>1614710662</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>hobart</td>
#       <td>-42.8794</td>
#       <td>147.3294</td>
# ...
